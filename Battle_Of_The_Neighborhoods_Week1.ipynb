# %% [markdown]
# ### IBM Data Science Capstone Project - Battle of the Neighborhoods Week 1

# %% [markdown]
# ###### By Martin Palkovic, Geoscientist at Colorado School of Mines

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ### Week 1

# %% [markdown]
# #### Description of the problem and a discussion of the background

# %% [markdown]
# ##### For this project, I'll be determining where a good location would be to build a new brewery in the city of Denver. I live in Denver, and I thought it would be fun to step away from Toronto and New York City to work on a project a bit closer to home. I'll do this by downloading data from the city of Denver's website for each neighborhood in the city, calling the Foursquare API to get data on venues in each neighborhood, and finally, run a machine learning algorithm to help determine which neighborhood our brewery should go in.

# %% [markdown]
# #### Description of the data and how it will be used to solve the problem

# %% [markdown]
# ##### For this project, I'll be utilizing the city of Denver's 'Statistical Neighborhoods' dataset (https://www.denvergov.org/opendata/dataset/city-and-county-of-denver-statistical-neighborhoods), which I'll map in Folium as polygons. I'll also be using venue data from the Foursquare API, which I'll clean, and eventually run through the K-Means machine learning algorithm (https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) to determine where we should build a new brewery in Denver!
